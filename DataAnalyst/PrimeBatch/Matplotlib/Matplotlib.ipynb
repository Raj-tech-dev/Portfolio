# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4]
y = [4,5,6,7]
plt.plot(x,y) # this is use for  line plot 
plt.show() #this is use for showing/ present

# %%
# make chart of wining oscar rewards in years
oscar_movies = [
    "tera baap",
    "Tu mera hero",
    "Jani Dushamn",
    "Jindagi",
    "kaise ho",
    "jina "
]
year = [2000, 2001, 2002, 2003,2004, 2005]
oscar_revanue = [123, 254, 125, 421, 235, 154]
plt.plot(year, oscar_revanue, label = "oscar_revanue")

plt.title("Oscar winning vs non_oscar winning Revanue")
plt.xlabel("Year")
plt.ylabel("Revanue (in $m)")

non_osacr_movie = ["jani Dushaman", "hera pheri", "Don", "Don2", "Krish", "Krish2"]
year = [2000, 2001, 2002, 2003,2004, 2005]
non_oscar_revanue = [133, 204, 105, 141, 200, 104]
plt.plot(year, non_oscar_revanue, label = "non_oscar_revanue")

plt.legend()

# %%
Student_Name = [
    "Raj",
    "Karan",
    "Raja",
    "Sabdeep",
    "Ashish",
    "Somya"
]
Admission_Year = [2000, 2001, 2002, 2008, 2004, 2005]
plt.bar(Student_Name, Admission_Year)
plt.xlabel("Name")
plt.ylabel("year")
for i in range(len(Admission_Year)):
    plt.text(Student_Name[i], Admission_Year[i]+20, str(Admission_Year[0]), ha = "center")
plt.ylim(0, max(Admission_Year)+100)
# Out:
# (0.0, 2108.0)
